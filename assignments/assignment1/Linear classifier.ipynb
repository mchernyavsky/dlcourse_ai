# %% [markdown]
# # Задание 1.2 - Линейный классификатор (Linear classifier)
#
# В этом задании мы реализуем другую модель машинного обучения - линейный классификатор. Линейный классификатор подбирает для каждого класса веса, на которые нужно умножить значение каждого признака и потом сложить вместе.
# Тот класс, у которого эта сумма больше, и является предсказанием модели.
#
# В этом задании вы:
# - потренируетесь считать градиенты различных многомерных функций
# - реализуете подсчет градиентов через линейную модель и функцию потерь softmax
# - реализуете процесс тренировки линейного классификатора
# - подберете параметры тренировки на практике
#
# На всякий случай, еще раз ссылка на туториал по numpy:
# http://cs231n.github.io/python-numpy-tutorial/

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
from dataset import load_svhn, random_split_train_val
from gradient_check import check_gradient
from metrics import multiclass_accuracy 
import linear_classifer

# %% [markdown]
# # Как всегда, первым делом загружаем данные
#
# Мы будем использовать все тот же SVHN.

# %%
def prepare_for_linear_classifier(train_X, test_X):
    train_flat = train_X.reshape(train_X.shape[0], -1).astype(np.float) / 255.0
    test_flat = test_X.reshape(test_X.shape[0], -1).astype(np.float) / 255.0
    
    # Subtract mean
    mean_image = np.mean(train_flat, axis = 0)
    train_flat -= mean_image
    test_flat -= mean_image
    
    # Add another channel with ones as a bias term
    train_flat_with_ones = np.hstack([train_flat, np.ones((train_X.shape[0], 1))])
    test_flat_with_ones = np.hstack([test_flat, np.ones((test_X.shape[0], 1))])    
    return train_flat_with_ones, test_flat_with_ones
    
train_X, train_y, test_X, test_y = load_svhn("data", max_train=10000, max_test=1000)    
train_X, test_X = prepare_for_linear_classifier(train_X, test_X)
# Split train into train and val
train_X, train_y, val_X, val_y = random_split_train_val(train_X, train_y, num_val = 1000)

# %% [markdown]
# # Играемся с градиентами!
#
# В этом курсе мы будем писать много функций, которые вычисляют градиенты аналитическим методом.
#
# Все функции, в которых мы будем вычислять градиенты, будут написаны по одной и той же схеме.
# Они будут получать на вход точку, где нужно вычислить значение и градиент функции, а на выходе будут выдавать кортеж (tuple) из двух значений - собственно значения функции в этой точке (всегда одно число) и аналитического значения градиента в той же точке (той же размерности, что и вход).
# ```
# def f(x):
#     """
#     Computes function and analytic gradient at x
#
#     x: np array of float, input to the function
#
#     Returns:
#     value: float, value of the function
#     grad: np array of float, same shape as x
#     """
#     ...
#
#     return value, grad
# ```
#
# Необходимым инструментом во время реализации кода, вычисляющего градиенты, является функция его проверки. Эта функция вычисляет градиент численным методом и сверяет результат с градиентом, вычисленным аналитическим методом.
#
# Мы начнем с того, чтобы реализовать вычисление численного градиента (numeric gradient) в функции `check_gradient` в `gradient_check.py`. Эта функция будет принимать на вход функции формата, заданного выше, использовать значение `value` для вычисления численного градиента и сравнит его с аналитическим - они должны сходиться.
#
# Напишите часть функции, которая вычисляет градиент с помощью численной производной для каждой координаты. Для вычисления производной используйте так называемую two-point formula (https://en.wikipedia.org/wiki/Numerical_differentiation):
#
# ![image](https://wikimedia.org/api/rest_v1/media/math/render/svg/22fc2c0a66c63560a349604f8b6b39221566236d)
#
# Все функции приведенные в следующей клетке должны проходить gradient check.

# %%
# All the functions below should pass the gradient check

def square(x):
    return float(x*x), 2*x

check_gradient(square, np.array([3.0]))

def array_sum(x):
    assert x.shape == (2,), x.shape
    return np.sum(x), np.ones_like(x)

check_gradient(array_sum, np.array([3.0, 2.0]))

def array_2d_sum(x):
    assert x.shape == (2,2)
    return np.sum(x), np.ones_like(x)

check_gradient(array_2d_sum, np.array([[3.0, 2.0], [1.0, 0.0]]))
# Out:
# Gradient check passed!
# Gradient check passed!
# Gradient check passed!
# True

# %% [markdown]
# ## Начинаем писать свои функции, считающие аналитический градиент
#
# Теперь реализуем функцию softmax, которая получает на вход оценки для каждого класса и преобразует их в вероятности от 0 до 1:
# ![image](https://wikimedia.org/api/rest_v1/media/math/render/svg/e348290cf48ddbb6e9a6ef4e39363568b67c09d3)
#
# **Важно:** Практический аспект вычисления этой функции заключается в том, что в ней учавствует вычисление экспоненты от потенциально очень больших чисел - это может привести к очень большим значениям в числителе и знаменателе за пределами диапазона float.
#
# К счастью, у этой проблемы есть простое решение -- перед вычислением softmax вычесть из всех оценок максимальное значение среди всех оценок:
# ```
# predictions -= np.max(predictions)
# ```
# (подробнее здесь - http://cs231n.github.io/linear-classify/#softmax, секция `Practical issues: Numeric stability`)

# %%
# Softmax and cross-entropy for single sample
probs = linear_classifer.softmax(np.array([-10, 0, 10]))

# Make sure it works for big numbers too!
probs = linear_classifer.softmax(np.array([1000, 0, 0]))
assert np.isclose(probs[0], 1.0)

# %% [markdown]
# Кроме этого, мы реализуем cross-entropy loss, которую мы будем использовать как функцию ошибки (error function).
# В общем виде cross-entropy определена следующим образом:
# ![image](https://wikimedia.org/api/rest_v1/media/math/render/svg/0cb6da032ab424eefdca0884cd4113fe578f4293)
#
# где x - все классы, p(x) - истинная вероятность принадлежности сэмпла классу x, а q(x) - вероятность принадлежности классу x, предсказанная моделью.
# В нашем случае сэмпл принадлежит только одному классу, индекс которого передается функции. Для него p(x) равна 1, а для остальных классов - 0.
#
# Это позволяет реализовать функцию проще!

# %%
probs = linear_classifer.softmax(np.array([-5, 0, 5]))
linear_classifer.cross_entropy_loss(probs, 1)
# Out:
# 5.006760443547122

# %% [markdown]
# После того как мы реализовали сами функции, мы можем реализовать градиент.
#
# Оказывается, что вычисление градиента становится гораздо проще, если объединить эти функции в одну, которая сначала вычисляет вероятности через softmax, а потом использует их для вычисления функции ошибки через cross-entropy loss.
#
# Эта функция `softmax_with_cross_entropy` будет возвращает и значение ошибки, и градиент по входным параметрам. Мы проверим корректность реализации с помощью `check_gradient`.

# %%
# Combined function or softmax and cross entropy and produces gradient
loss, grad = linear_classifer.softmax_with_cross_entropy(np.array([1, 0, 0]), 1)
check_gradient(lambda x: linear_classifer.softmax_with_cross_entropy(x, 1), np.array([1, 0, 0], np.float))
# Out:
# Gradient check passed!
# True

# %% [markdown]
# В качестве метода тренировки мы будем использовать стохастический градиентный спуск (stochastic gradient descent или SGD), который работает с батчами сэмплов.
#
# Поэтому все наши фукнции будут получать не один пример, а батч, то есть входом будет не вектор из `num_classes` оценок, а матрица размерности `batch_size, num_classes`. Индекс примера в батче всегда будет первым измерением.
#
# Следующий шаг - переписать наши функции так, чтобы они поддерживали батчи.
#
# Финальное значение функции ошибки должно остаться числом, и оно равно среднему значению ошибки среди всех примеров в батче.

# %%
# Extend combined function so it can receive a 2d array with batch of samples
np.random.seed(42)

# Test batch_size = 1
num_classes = 4
batch_size = 1
predictions = np.random.randint(-1, 3, size=(batch_size, num_classes)).astype(np.float)
target_index = np.random.randint(0, num_classes, size=(batch_size, 1)).astype(np.int)
check_gradient(lambda x: linear_classifer.softmax_with_cross_entropy(x, target_index), predictions)

# Test batch_size = 3
num_classes = 4
batch_size = 3
predictions = np.random.randint(-1, 3, size=(batch_size, num_classes)).astype(np.float)
target_index = np.random.randint(0, num_classes, size=(batch_size, 1)).astype(np.int)
check_gradient(lambda x: linear_classifer.softmax_with_cross_entropy(x, target_index), predictions)

# Make sure maximum subtraction for numberic stability is done separately for every sample in the batch
probs = linear_classifer.softmax(np.array([[20,0,0], [1000, 0, 0]]))
assert np.all(np.isclose(probs[:, 0], 1.0))
# Out:
# Gradient check passed!
# Gradients are different at (0, 2). Analytic: -0.32202, Numeric: -0.09980

# %% [markdown]
# ### Наконец, реализуем сам линейный классификатор!
#
# softmax и cross-entropy получают на вход оценки, которые выдает линейный классификатор.
#
# Он делает это очень просто: для каждого класса есть набор весов, на которые надо умножить пиксели картинки и сложить. Получившееся число и является оценкой класса, идущей на вход softmax.
#
# Таким образом, линейный классификатор можно представить как умножение вектора с пикселями на матрицу W размера `num_features, num_classes`. Такой подход легко расширяется на случай батча векторов с пикселями X размера `batch_size, num_features`:
#
# `predictions = X * W`, где `*` - матричное умножение.
#
# Реализуйте функцию подсчета линейного классификатора и градиентов по весам `linear_softmax` в файле `linear_classifer.py`

# %%
# Implement linear_softmax function that uses softmax with cross-entropy for linear classifier
batch_size = 2
num_classes = 2
num_features = 3
np.random.seed(42)
W = np.random.randint(-1, 3, size=(num_features, num_classes)).astype(np.float)
X = np.random.randint(-1, 3, size=(batch_size, num_features)).astype(np.float)
target_index = np.ones(batch_size, dtype=np.int)

loss, dW = linear_classifer.linear_softmax(X, W, target_index)
check_gradient(lambda w: linear_classifer.linear_softmax(X, w, target_index), W)
# Out:
# Gradient check passed!
# True

# %% [markdown]
# ### И теперь регуляризация
#
# Мы будем использовать L2 regularization для весов как часть общей функции ошибки.
#
# Напомним, L2 regularization определяется как
#
# l2_reg_loss = regularization_strength * sum<sub>ij</sub> W[i, j]<sup>2</sup>
#
# Реализуйте функцию для его вычисления и вычисления соотвествующих градиентов.

# %%
# Implement l2_regularization function that implements loss for L2 regularization
linear_classifer.l2_regularization(W, 0.01)
check_gradient(lambda w: linear_classifer.l2_regularization(w, 0.01), W)
# Out:
# Gradient check passed!
# True

# %% [markdown]
# # Тренировка!

# %% [markdown]
# Градиенты в порядке, реализуем процесс тренировки!

# %%
# Implement LinearSoftmaxClassifier.fit function
classifier = linear_classifer.LinearSoftmaxClassifier()
loss_history = classifier.fit(train_X, train_y, epochs=10, learning_rate=1e-3, batch_size=300, reg=1e1)
# Out:
# Epoch 0, loss: 2.397363
# Epoch 1, loss: 2.330354
# Epoch 2, loss: 2.311002
# Epoch 3, loss: 2.303897
# Epoch 4, loss: 2.303257
# Epoch 5, loss: 2.302898
# Epoch 6, loss: 2.302564
# Epoch 7, loss: 2.301815
# Epoch 8, loss: 2.301252
# Epoch 9, loss: 2.301256

# %%
# Let's look at the loss history!
plt.plot(loss_history)

# %%
# Let's check how it performs on validation set
pred = classifier.predict(val_X)
accuracy = multiclass_accuracy(pred, val_y)
print("Accuracy: ", accuracy)

# Now, let's train more and see if it performs better
classifier.fit(train_X, train_y, epochs=100, learning_rate=1e-3, batch_size=300, reg=1e1)
pred = classifier.predict(val_X)
accuracy = multiclass_accuracy(pred, val_y)
print("Accuracy after training for 100 epochs: ", accuracy)
# Out:
# Accuracy:  0.127
# Epoch 0, loss: 2.301800
# Epoch 1, loss: 2.302558
# Epoch 2, loss: 2.302208
# Epoch 3, loss: 2.303309
# Epoch 4, loss: 2.302126
# Epoch 5, loss: 2.301524
# Epoch 6, loss: 2.301150
# Epoch 7, loss: 2.301359
# Epoch 8, loss: 2.302305
# Epoch 9, loss: 2.302205
# Epoch 10, loss: 2.301595
# Epoch 11, loss: 2.302039
# Epoch 12, loss: 2.301247
# Epoch 13, loss: 2.301836
# Epoch 14, loss: 2.302396
# Epoch 15, loss: 2.302299
# Epoch 16, loss: 2.301161
# Epoch 17, loss: 2.302058
# Epoch 18, loss: 2.302180
# Epoch 19, loss: 2.302339
# Epoch 20, loss: 2.302694
# Epoch 21, loss: 2.301872
# Epoch 22, loss: 2.302261
# Epoch 23, loss: 2.302209
# Epoch 24, loss: 2.302215
# Epoch 25, loss: 2.301591
# Epoch 26, loss: 2.301535
# Epoch 27, loss: 2.302557
# Epoch 28, loss: 2.301689
# Epoch 29, loss: 2.301815
# Epoch 30, loss: 2.301483
# Epoch 31, loss: 2.301553
# Epoch 32, loss: 2.301640
# Epoch 33, loss: 2.301991
# Epoch 34, loss: 2.302104
# Epoch 35, loss: 2.301741
# Epoch 36, loss: 2.302652
# Epoch 37, loss: 2.303017
# Epoch 38, loss: 2.301521
# Epoch 39, loss: 2.301504
# Epoch 40, loss: 2.301565
# Epoch 41, loss: 2.302361
# Epoch 42, loss: 2.302223
# Epoch 43, loss: 2.302385
# Epoch 44, loss: 2.302532
# Epoch 45, loss: 2.301950
# Epoch 46, loss: 2.301686
# Epoch 47, loss: 2.301881
# Epoch 48, loss: 2.302291
# Epoch 49, loss: 2.302069
# Epoch 50, loss: 2.301971
# Epoch 51, loss: 2.302533
# Epoch 52, loss: 2.302043
# Epoch 53, loss: 2.302003
# Epoch 54, loss: 2.301729
# Epoch 55, loss: 2.301272
# Epoch 56, loss: 2.302220
# Epoch 57, loss: 2.301765
# Epoch 58, loss: 2.301959
# Epoch 59, loss: 2.302229
# Epoch 60, loss: 2.301372
# Epoch 61, loss: 2.302540
# Epoch 62, loss: 2.301929
# Epoch 63, loss: 2.301502
# Epoch 64, loss: 2.302201
# Epoch 65, loss: 2.302674
# Epoch 66, loss: 2.302191
# Epoch 67, loss: 2.302989
# Epoch 68, loss: 2.301388
# Epoch 69, loss: 2.301621
# Epoch 70, loss: 2.301533
# Epoch 71, loss: 2.302804
# Epoch 72, loss: 2.301514
# Epoch 73, loss: 2.300962
# Epoch 74, loss: 2.302366
# Epoch 75, loss: 2.301895
# Epoch 76, loss: 2.301768
# Epoch 77, loss: 2.302649
# Epoch 78, loss: 2.302394
# Epoch 79, loss: 2.301415
# Epoch 80, loss: 2.302148
# Epoch 81, loss: 2.302263
# Epoch 82, loss: 2.301172
# Epoch 83, loss: 2.302803
# Epoch 84, loss: 2.301892
# Epoch 85, loss: 2.302788
# Epoch 86, loss: 2.302016
# Epoch 87, loss: 2.302450
# Epoch 88, loss: 2.302002
# Epoch 89, loss: 2.302363
# Epoch 90, loss: 2.301257
# Epoch 91, loss: 2.302553
# Epoch 92, loss: 2.301951
# Epoch 93, loss: 2.300910
# Epoch 94, loss: 2.302318
# Epoch 95, loss: 2.301563
# Epoch 96, loss: 2.302494
# Epoch 97, loss: 2.301579
# Epoch 98, loss: 2.302468
# Epoch 99, loss: 2.302352
# Accuracy after training for 100 epochs:  0.121

# %% [markdown]
# ### Как и раньше, используем кросс-валидацию для подбора гиперпараметтов.
#
# В этот раз, чтобы тренировка занимала разумное время, мы будем использовать только одно разделение на тренировочные (training) и проверочные (validation) данные.
#
# Теперь нам нужно подобрать не один, а два гиперпараметра! Не ограничивайте себя изначальными значениями в коде.
# Добейтесь точности более чем **20%** на проверочных данных (validation data).

# %%
num_epochs = 200
batch_size = 300

learning_rates = [1e-2, 1e-3]
reg_strengths = [1e-2, 1e-3]

best_classifier = None
best_val_accuracy = None

# Use validation set to find the best hyperparameters
for learning_rate in learning_rates:
    for reg_strength in reg_strengths:
        classifier = linear_classifer.LinearSoftmaxClassifier()
        classifier.fit(train_X, train_y, epochs=num_epochs, learning_rate=learning_rate,
                       batch_size=batch_size, reg=reg_strength)
        pred = classifier.predict(val_X)
        accuracy = multiclass_accuracy(pred, val_y)
        if best_val_accuracy is None or best_val_accuracy < accuracy:
            best_classifier = classifier
            best_val_accuracy = accuracy

print(f'Best validation accuracy achieved: {best_val_accuracy}')
# Out:
# Epoch 0, loss: 2.294992
# Epoch 1, loss: 2.289340
# Epoch 2, loss: 2.288648
# Epoch 3, loss: 2.274189
# Epoch 4, loss: 2.269967
# Epoch 5, loss: 2.257130
# Epoch 6, loss: 2.242764
# Epoch 7, loss: 2.258471
# Epoch 8, loss: 2.226391
# Epoch 9, loss: 2.222121
# Epoch 10, loss: 2.229842
# Epoch 11, loss: 2.224108
# Epoch 12, loss: 2.230435
# Epoch 13, loss: 2.239890
# Epoch 14, loss: 2.238267
# Epoch 15, loss: 2.188396
# Epoch 16, loss: 2.220747
# Epoch 17, loss: 2.184737
# Epoch 18, loss: 2.217605
# Epoch 19, loss: 2.201300
# Epoch 20, loss: 2.197612
# Epoch 21, loss: 2.187325
# Epoch 22, loss: 2.209376
# Epoch 23, loss: 2.222788
# Epoch 24, loss: 2.218259
# Epoch 25, loss: 2.191167
# Epoch 26, loss: 2.184945
# Epoch 27, loss: 2.216957
# Epoch 28, loss: 2.210757
# Epoch 29, loss: 2.249473
# Epoch 30, loss: 2.174443
# Epoch 31, loss: 2.198195
# Epoch 32, loss: 2.174903
# Epoch 33, loss: 2.182461
# Epoch 34, loss: 2.167751
# Epoch 35, loss: 2.194282
# Epoch 36, loss: 2.166460
# Epoch 37, loss: 2.211682
# Epoch 38, loss: 2.189374
# Epoch 39, loss: 2.171987
# Epoch 40, loss: 2.153881
# Epoch 41, loss: 2.176238
# Epoch 42, loss: 2.175907
# Epoch 43, loss: 2.191542
# Epoch 44, loss: 2.178684
# Epoch 45, loss: 2.162658
# Epoch 46, loss: 2.151085
# Epoch 47, loss: 2.189657
# Epoch 48, loss: 2.192746
# Epoch 49, loss: 2.188746
# Epoch 50, loss: 2.204913
# Epoch 51, loss: 2.200829
# Epoch 52, loss: 2.164953
# Epoch 53, loss: 2.158911
# Epoch 54, loss: 2.145260
# Epoch 55, loss: 2.207033
# Epoch 56, loss: 2.162220
# Epoch 57, loss: 2.161427
# Epoch 58, loss: 2.199597
# Epoch 59, loss: 2.169422
# Epoch 60, loss: 2.179019
# Epoch 61, loss: 2.188592
# Epoch 62, loss: 2.196213
# Epoch 63, loss: 2.143922
# Epoch 64, loss: 2.173416
# Epoch 65, loss: 2.179205
# Epoch 66, loss: 2.172878
# Epoch 67, loss: 2.179174
# Epoch 68, loss: 2.159176
# Epoch 69, loss: 2.199769
# Epoch 70, loss: 2.162214
# Epoch 71, loss: 2.183344
# Epoch 72, loss: 2.221301
# Epoch 73, loss: 2.165978
# Epoch 74, loss: 2.199365
# Epoch 75, loss: 2.143584
# Epoch 76, loss: 2.189195
# Epoch 77, loss: 2.186259
# Epoch 78, loss: 2.190745
# Epoch 79, loss: 2.138666
# Epoch 80, loss: 2.171062
# Epoch 81, loss: 2.211744
# Epoch 82, loss: 2.170028
# Epoch 83, loss: 2.112914
# Epoch 84, loss: 2.200141
# Epoch 85, loss: 2.196719
# Epoch 86, loss: 2.151031
# Epoch 87, loss: 2.153631
# Epoch 88, loss: 2.177241
# Epoch 89, loss: 2.160523
# Epoch 90, loss: 2.187771
# Epoch 91, loss: 2.169596
# Epoch 92, loss: 2.184999
# Epoch 93, loss: 2.166183
# Epoch 94, loss: 2.162723
# Epoch 95, loss: 2.171393
# Epoch 96, loss: 2.114396
# Epoch 97, loss: 2.211157
# Epoch 98, loss: 2.185920
# Epoch 99, loss: 2.191076
# Epoch 100, loss: 2.135699
# Epoch 101, loss: 2.192552
# Epoch 102, loss: 2.141143
# Epoch 103, loss: 2.157169
# Epoch 104, loss: 2.199420
# Epoch 105, loss: 2.169258
# Epoch 106, loss: 2.140314
# Epoch 107, loss: 2.158453
# Epoch 108, loss: 2.180709
# Epoch 109, loss: 2.156844
# Epoch 110, loss: 2.159031
# Epoch 111, loss: 2.199058
# Epoch 112, loss: 2.128356
# Epoch 113, loss: 2.179678
# Epoch 114, loss: 2.175775
# Epoch 115, loss: 2.193551
# Epoch 116, loss: 2.213397
# Epoch 117, loss: 2.103393
# Epoch 118, loss: 2.171946
# Epoch 119, loss: 2.190693
# Epoch 120, loss: 2.233483
# Epoch 121, loss: 2.144511
# Epoch 122, loss: 2.182644
# Epoch 123, loss: 2.157151
# Epoch 124, loss: 2.167140
# Epoch 125, loss: 2.152800
# Epoch 126, loss: 2.155727
# Epoch 127, loss: 2.136631
# Epoch 128, loss: 2.166878
# Epoch 129, loss: 2.143587
# Epoch 130, loss: 2.138494
# Epoch 131, loss: 2.163792
# Epoch 132, loss: 2.157687
# Epoch 133, loss: 2.168243
# Epoch 134, loss: 2.166667
# Epoch 135, loss: 2.172026
# Epoch 136, loss: 2.136586
# Epoch 137, loss: 2.128907
# Epoch 138, loss: 2.148415
# Epoch 139, loss: 2.151891
# Epoch 140, loss: 2.143354
# Epoch 141, loss: 2.128667
# Epoch 142, loss: 2.167386
# Epoch 143, loss: 2.214052
# Epoch 144, loss: 2.153202
# Epoch 145, loss: 2.170675
# Epoch 146, loss: 2.170805
# Epoch 147, loss: 2.173680
# Epoch 148, loss: 2.171516
# Epoch 149, loss: 2.148228
# Epoch 150, loss: 2.199052
# Epoch 151, loss: 2.188821
# Epoch 152, loss: 2.177321
# Epoch 153, loss: 2.184788
# Epoch 154, loss: 2.203284
# Epoch 155, loss: 2.184592
# Epoch 156, loss: 2.189718
# Epoch 157, loss: 2.183663
# Epoch 158, loss: 2.169308
# Epoch 159, loss: 2.150098
# Epoch 160, loss: 2.142545
# Epoch 161, loss: 2.145711
# Epoch 162, loss: 2.152030
# Epoch 163, loss: 2.135501
# Epoch 164, loss: 2.207951
# Epoch 165, loss: 2.148678
# Epoch 166, loss: 2.145777
# Epoch 167, loss: 2.145022
# Epoch 168, loss: 2.162273
# Epoch 169, loss: 2.144069
# Epoch 170, loss: 2.114466
# Epoch 171, loss: 2.149343
# Epoch 172, loss: 2.139199
# Epoch 173, loss: 2.193683
# Epoch 174, loss: 2.135747
# Epoch 175, loss: 2.170218
# Epoch 176, loss: 2.136597
# Epoch 177, loss: 2.187993
# Epoch 178, loss: 2.160029
# Epoch 179, loss: 2.149437
# Epoch 180, loss: 2.170479
# Epoch 181, loss: 2.193341
# Epoch 182, loss: 2.219020
# Epoch 183, loss: 2.150631
# Epoch 184, loss: 2.197709
# Epoch 185, loss: 2.163174
# Epoch 186, loss: 2.157469
# Epoch 187, loss: 2.189922
# Epoch 188, loss: 2.153323
# Epoch 189, loss: 2.140790
# Epoch 190, loss: 2.154039
# Epoch 191, loss: 2.199643
# Epoch 192, loss: 2.184520
# Epoch 193, loss: 2.111963
# Epoch 194, loss: 2.137501
# Epoch 195, loss: 2.175831
# Epoch 196, loss: 2.173260
# Epoch 197, loss: 2.169169
# Epoch 198, loss: 2.178022
# Epoch 199, loss: 2.133737
# Epoch 0, loss: 2.293025
# Epoch 1, loss: 2.283732
# Epoch 2, loss: 2.279085
# Epoch 3, loss: 2.268918
# Epoch 4, loss: 2.258560
# Epoch 5, loss: 2.244740
# Epoch 6, loss: 2.226501
# Epoch 7, loss: 2.237337
# Epoch 8, loss: 2.257520
# Epoch 9, loss: 2.240952
# Epoch 10, loss: 2.226418
# Epoch 11, loss: 2.230898
# Epoch 12, loss: 2.227690
# Epoch 13, loss: 2.245613
# Epoch 14, loss: 2.192276
# Epoch 15, loss: 2.228031
# Epoch 16, loss: 2.200006
# Epoch 17, loss: 2.202052
# Epoch 18, loss: 2.224540
# Epoch 19, loss: 2.203195
# Epoch 20, loss: 2.177549
# Epoch 21, loss: 2.207438
# Epoch 22, loss: 2.193678
# Epoch 23, loss: 2.206290
# Epoch 24, loss: 2.216739
# Epoch 25, loss: 2.188145
# Epoch 26, loss: 2.200293
# Epoch 27, loss: 2.148386
# Epoch 28, loss: 2.211109
# Epoch 29, loss: 2.165579
# Epoch 30, loss: 2.136455
# Epoch 31, loss: 2.189832
# Epoch 32, loss: 2.201846
# Epoch 33, loss: 2.153329
# Epoch 34, loss: 2.157147
# Epoch 35, loss: 2.169744
# Epoch 36, loss: 2.116738
# Epoch 37, loss: 2.172717
# Epoch 38, loss: 2.143841
# Epoch 39, loss: 2.174036
# Epoch 40, loss: 2.121329
# Epoch 41, loss: 2.188221
# Epoch 42, loss: 2.188228
# Epoch 43, loss: 2.142904
# Epoch 44, loss: 2.181093
# Epoch 45, loss: 2.180408
# Epoch 46, loss: 2.171880
# Epoch 47, loss: 2.187103
# Epoch 48, loss: 2.112046
# Epoch 49, loss: 2.180301
# Epoch 50, loss: 2.113579
# Epoch 51, loss: 2.124897
# Epoch 52, loss: 2.127623
# Epoch 53, loss: 2.184183
# Epoch 54, loss: 2.108406
# Epoch 55, loss: 2.131691
# Epoch 56, loss: 2.188944
# Epoch 57, loss: 2.145419
# Epoch 58, loss: 2.160142
# Epoch 59, loss: 2.163179
# Epoch 60, loss: 2.167058
# Epoch 61, loss: 2.124777
# Epoch 62, loss: 2.126130
# Epoch 63, loss: 2.156156
# Epoch 64, loss: 2.140484
# Epoch 65, loss: 2.198615
# Epoch 66, loss: 2.143553
# Epoch 67, loss: 2.189645
# Epoch 68, loss: 2.203683
# Epoch 69, loss: 2.107729
# Epoch 70, loss: 2.158006
# Epoch 71, loss: 2.157186
# Epoch 72, loss: 2.098334
# Epoch 73, loss: 2.134575
# Epoch 74, loss: 2.184156
# Epoch 75, loss: 2.121068
# Epoch 76, loss: 2.165080
# Epoch 77, loss: 2.131185
# Epoch 78, loss: 2.086077
# Epoch 79, loss: 2.143952
# Epoch 80, loss: 2.123637
# Epoch 81, loss: 2.141614
# Epoch 82, loss: 2.127577
# Epoch 83, loss: 2.118405
# Epoch 84, loss: 2.166665
# Epoch 85, loss: 2.118096
# Epoch 86, loss: 2.157651
# Epoch 87, loss: 2.170245
# Epoch 88, loss: 2.145539
# Epoch 89, loss: 2.176239
# Epoch 90, loss: 2.079898
# Epoch 91, loss: 2.143822
# Epoch 92, loss: 2.097940
# Epoch 93, loss: 2.157505
# Epoch 94, loss: 2.167115
# Epoch 95, loss: 2.134610
# Epoch 96, loss: 2.134785
# Epoch 97, loss: 2.109186
# Epoch 98, loss: 2.136067
# Epoch 99, loss: 2.182427
# Epoch 100, loss: 2.147266
# Epoch 101, loss: 2.148766
# Epoch 102, loss: 2.143847
# Epoch 103, loss: 2.156306
# Epoch 104, loss: 2.187323
# Epoch 105, loss: 2.121182
# Epoch 106, loss: 2.107835
# Epoch 107, loss: 2.103568
# Epoch 108, loss: 2.149277
# Epoch 109, loss: 2.118725
# Epoch 110, loss: 2.154730
# Epoch 111, loss: 2.123414
# Epoch 112, loss: 2.194426
# Epoch 113, loss: 2.137029
# Epoch 114, loss: 2.126171
# Epoch 115, loss: 2.161777
# Epoch 116, loss: 2.112668
# Epoch 117, loss: 2.157556
# Epoch 118, loss: 2.119104
# Epoch 119, loss: 2.205755
# Epoch 120, loss: 2.137301
# Epoch 121, loss: 2.129842
# Epoch 122, loss: 2.127525
# Epoch 123, loss: 2.132490
# Epoch 124, loss: 2.094300
# Epoch 125, loss: 2.146686
# Epoch 126, loss: 2.072592
# Epoch 127, loss: 2.088007
# Epoch 128, loss: 2.119017
# Epoch 129, loss: 2.135147
# Epoch 130, loss: 2.132451
# Epoch 131, loss: 2.156175
# Epoch 132, loss: 2.140918
# Epoch 133, loss: 2.103795
# Epoch 134, loss: 2.090878
# Epoch 135, loss: 2.128523
# Epoch 136, loss: 2.083893
# Epoch 137, loss: 2.124483
# Epoch 138, loss: 2.105867
# Epoch 139, loss: 2.145557
# Epoch 140, loss: 2.141296
# Epoch 141, loss: 2.111573
# Epoch 142, loss: 2.143358
# Epoch 143, loss: 2.132448
# Epoch 144, loss: 2.107687
# Epoch 145, loss: 2.132374
# Epoch 146, loss: 2.107426
# Epoch 147, loss: 2.153499
# Epoch 148, loss: 2.075692
# Epoch 149, loss: 2.124227
# Epoch 150, loss: 2.078123
# Epoch 151, loss: 2.154971
# Epoch 152, loss: 2.150644
# Epoch 153, loss: 2.133115
# Epoch 154, loss: 2.151064
# Epoch 155, loss: 2.095484
# Epoch 156, loss: 2.103125
# Epoch 157, loss: 2.133805
# Epoch 158, loss: 2.158790
# Epoch 159, loss: 2.105784
# Epoch 160, loss: 2.141099
# Epoch 161, loss: 2.099756
# Epoch 162, loss: 2.166459
# Epoch 163, loss: 2.088707
# Epoch 164, loss: 2.080533
# Epoch 165, loss: 2.087059
# Epoch 166, loss: 2.084468
# Epoch 167, loss: 2.096794
# Epoch 168, loss: 2.172315
# Epoch 169, loss: 2.081081
# Epoch 170, loss: 2.088262
# Epoch 171, loss: 2.114089
# Epoch 172, loss: 2.141113
# Epoch 173, loss: 2.085711
# Epoch 174, loss: 2.128942
# Epoch 175, loss: 2.131670
# Epoch 176, loss: 2.082754
# Epoch 177, loss: 2.112378
# Epoch 178, loss: 2.127847
# Epoch 179, loss: 2.088497
# Epoch 180, loss: 2.095803
# Epoch 181, loss: 2.100338
# Epoch 182, loss: 2.137934
# Epoch 183, loss: 2.142801
# Epoch 184, loss: 2.133673
# Epoch 185, loss: 2.139196
# Epoch 186, loss: 2.118654
# Epoch 187, loss: 2.091857
# Epoch 188, loss: 2.113613
# Epoch 189, loss: 2.076912
# Epoch 190, loss: 2.089904
# Epoch 191, loss: 2.080098
# Epoch 192, loss: 2.093050
# Epoch 193, loss: 2.121585
# Epoch 194, loss: 2.122828
# Epoch 195, loss: 2.127150
# Epoch 196, loss: 2.074080
# Epoch 197, loss: 2.119835
# Epoch 198, loss: 2.054540
# Epoch 199, loss: 2.120013
# Epoch 0, loss: 2.302435
# Epoch 1, loss: 2.300731
# Epoch 2, loss: 2.297979
# Epoch 3, loss: 2.298610
# Epoch 4, loss: 2.298142
# Epoch 5, loss: 2.296902
# Epoch 6, loss: 2.294154
# Epoch 7, loss: 2.295308
# Epoch 8, loss: 2.294378
# Epoch 9, loss: 2.292737
# Epoch 10, loss: 2.287975
# Epoch 11, loss: 2.294581
# Epoch 12, loss: 2.293746
# Epoch 13, loss: 2.291687
# Epoch 14, loss: 2.286790
# Epoch 15, loss: 2.291498
# Epoch 16, loss: 2.286203
# Epoch 17, loss: 2.290534
# Epoch 18, loss: 2.286982
# Epoch 19, loss: 2.283422
# Epoch 20, loss: 2.287678
# Epoch 21, loss: 2.288508
# Epoch 22, loss: 2.279668
# Epoch 23, loss: 2.283698
# Epoch 24, loss: 2.281274
# Epoch 25, loss: 2.282644
# Epoch 26, loss: 2.282397
# Epoch 27, loss: 2.278894
# Epoch 28, loss: 2.284828
# Epoch 29, loss: 2.276575
# Epoch 30, loss: 2.280977
# Epoch 31, loss: 2.274805
# Epoch 32, loss: 2.273721
# Epoch 33, loss: 2.274935
# Epoch 34, loss: 2.283139
# Epoch 35, loss: 2.271415
# Epoch 36, loss: 2.278364
# Epoch 37, loss: 2.266581
# Epoch 38, loss: 2.274536
# Epoch 39, loss: 2.264465
# Epoch 40, loss: 2.264911
# Epoch 41, loss: 2.274340
# Epoch 42, loss: 2.266561
# Epoch 43, loss: 2.272638
# Epoch 44, loss: 2.268550
# Epoch 45, loss: 2.277156
# Epoch 46, loss: 2.264961
# Epoch 47, loss: 2.265771
# Epoch 48, loss: 2.268070
# Epoch 49, loss: 2.265500
# Epoch 50, loss: 2.263980
# Epoch 51, loss: 2.266593
# Epoch 52, loss: 2.258334
# Epoch 53, loss: 2.269904
# Epoch 54, loss: 2.264665
# Epoch 55, loss: 2.258886
# Epoch 56, loss: 2.272825
# Epoch 57, loss: 2.250918
# Epoch 58, loss: 2.257496
# Epoch 59, loss: 2.258907
# Epoch 60, loss: 2.263046
# Epoch 61, loss: 2.256058
# Epoch 62, loss: 2.260482
# Epoch 63, loss: 2.253782
# Epoch 64, loss: 2.248921
# Epoch 65, loss: 2.259740
# Epoch 66, loss: 2.255227
# Epoch 67, loss: 2.267141
# Epoch 68, loss: 2.249410
# Epoch 69, loss: 2.256925
# Epoch 70, loss: 2.246925
# Epoch 71, loss: 2.250813
# Epoch 72, loss: 2.266747
# Epoch 73, loss: 2.262789
# Epoch 74, loss: 2.258755
# Epoch 75, loss: 2.250712
# Epoch 76, loss: 2.266639
# Epoch 77, loss: 2.247503
# Epoch 78, loss: 2.258888
# Epoch 79, loss: 2.250122
# Epoch 80, loss: 2.250543
# Epoch 81, loss: 2.240084
# Epoch 82, loss: 2.244868
# Epoch 83, loss: 2.261222
# Epoch 84, loss: 2.235344
# Epoch 85, loss: 2.253575
# Epoch 86, loss: 2.239090
# Epoch 87, loss: 2.262988
# Epoch 88, loss: 2.243577
# Epoch 89, loss: 2.240707
# Epoch 90, loss: 2.240059
# Epoch 91, loss: 2.243499
# Epoch 92, loss: 2.237610
# Epoch 93, loss: 2.249130
# Epoch 94, loss: 2.249188
# Epoch 95, loss: 2.242320
# Epoch 96, loss: 2.256304
# Epoch 97, loss: 2.244578
# Epoch 98, loss: 2.237039
# Epoch 99, loss: 2.233811
# Epoch 100, loss: 2.236538
# Epoch 101, loss: 2.244981
# Epoch 102, loss: 2.226969
# Epoch 103, loss: 2.242208
# Epoch 104, loss: 2.235265
# Epoch 105, loss: 2.261483
# Epoch 106, loss: 2.251884
# Epoch 107, loss: 2.233067
# Epoch 108, loss: 2.235708
# Epoch 109, loss: 2.230214
# Epoch 110, loss: 2.237422
# Epoch 111, loss: 2.239849
# Epoch 112, loss: 2.215903
# Epoch 113, loss: 2.225408
# Epoch 114, loss: 2.236757
# Epoch 115, loss: 2.225487
# Epoch 116, loss: 2.242632
# Epoch 117, loss: 2.216117
# Epoch 118, loss: 2.227475
# Epoch 119, loss: 2.251282
# Epoch 120, loss: 2.232483
# Epoch 121, loss: 2.236500
# Epoch 122, loss: 2.244871
# Epoch 123, loss: 2.232711
# Epoch 124, loss: 2.243872
# Epoch 125, loss: 2.238320
# Epoch 126, loss: 2.234590
# Epoch 127, loss: 2.237305
# Epoch 128, loss: 2.206224
# Epoch 129, loss: 2.250251
# Epoch 130, loss: 2.236985
# Epoch 131, loss: 2.233973
# Epoch 132, loss: 2.224754
# Epoch 133, loss: 2.234534
# Epoch 134, loss: 2.218171
# Epoch 135, loss: 2.233960
# Epoch 136, loss: 2.220034
# Epoch 137, loss: 2.206574
# Epoch 138, loss: 2.218468
# Epoch 139, loss: 2.220611
# Epoch 140, loss: 2.231835
# Epoch 141, loss: 2.222677
# Epoch 142, loss: 2.239181
# Epoch 143, loss: 2.222297
# Epoch 144, loss: 2.226366
# Epoch 145, loss: 2.257171
# Epoch 146, loss: 2.240745
# Epoch 147, loss: 2.219004
# Epoch 148, loss: 2.212320
# Epoch 149, loss: 2.222181
# Epoch 150, loss: 2.236503
# Epoch 151, loss: 2.227286
# Epoch 152, loss: 2.245792
# Epoch 153, loss: 2.220112
# Epoch 154, loss: 2.192938
# Epoch 155, loss: 2.215389
# Epoch 156, loss: 2.222266
# Epoch 157, loss: 2.239795
# Epoch 158, loss: 2.235240
# Epoch 159, loss: 2.230479
# Epoch 160, loss: 2.207719
# Epoch 161, loss: 2.218492
# Epoch 162, loss: 2.227625
# Epoch 163, loss: 2.188991
# Epoch 164, loss: 2.192148
# Epoch 165, loss: 2.222983
# Epoch 166, loss: 2.196056
# Epoch 167, loss: 2.223649
# Epoch 168, loss: 2.229853
# Epoch 169, loss: 2.221195
# Epoch 170, loss: 2.212163
# Epoch 171, loss: 2.215360
# Epoch 172, loss: 2.219967
# Epoch 173, loss: 2.198487
# Epoch 174, loss: 2.221271
# Epoch 175, loss: 2.224851
# Epoch 176, loss: 2.184820
# Epoch 177, loss: 2.198724
# Epoch 178, loss: 2.223539
# Epoch 179, loss: 2.207737
# Epoch 180, loss: 2.221354
# Epoch 181, loss: 2.206924
# Epoch 182, loss: 2.233707
# Epoch 183, loss: 2.198505
# Epoch 184, loss: 2.211812
# Epoch 185, loss: 2.209494
# Epoch 186, loss: 2.214410
# Epoch 187, loss: 2.183831
# Epoch 188, loss: 2.171588
# Epoch 189, loss: 2.210178
# Epoch 190, loss: 2.228936
# Epoch 191, loss: 2.195176
# Epoch 192, loss: 2.211614
# Epoch 193, loss: 2.225804
# Epoch 194, loss: 2.215791
# Epoch 195, loss: 2.223888
# Epoch 196, loss: 2.215080
# Epoch 197, loss: 2.222891
# Epoch 198, loss: 2.220599
# Epoch 199, loss: 2.201737
# Epoch 0, loss: 2.301280
# Epoch 1, loss: 2.303496
# Epoch 2, loss: 2.300718
# Epoch 3, loss: 2.299184
# Epoch 4, loss: 2.299476
# Epoch 5, loss: 2.297414
# Epoch 6, loss: 2.293261
# Epoch 7, loss: 2.295059
# Epoch 8, loss: 2.298728
# Epoch 9, loss: 2.292494
# Epoch 10, loss: 2.291593
# Epoch 11, loss: 2.292875
# Epoch 12, loss: 2.288012
# Epoch 13, loss: 2.289688
# Epoch 14, loss: 2.287660
# Epoch 15, loss: 2.287970
# Epoch 16, loss: 2.289625
# Epoch 17, loss: 2.285711
# Epoch 18, loss: 2.286228
# Epoch 19, loss: 2.288035
# Epoch 20, loss: 2.283658
# Epoch 21, loss: 2.286273
# Epoch 22, loss: 2.283362
# Epoch 23, loss: 2.284235
# Epoch 24, loss: 2.283564
# Epoch 25, loss: 2.277756
# Epoch 26, loss: 2.279572
# Epoch 27, loss: 2.282282
# Epoch 28, loss: 2.276848
# Epoch 29, loss: 2.286499
# Epoch 30, loss: 2.277347
# Epoch 31, loss: 2.281849
# Epoch 32, loss: 2.276534
# Epoch 33, loss: 2.279525
# Epoch 34, loss: 2.273644
# Epoch 35, loss: 2.276440
# Epoch 36, loss: 2.269520
# Epoch 37, loss: 2.275127
# Epoch 38, loss: 2.271582
# Epoch 39, loss: 2.259845
# Epoch 40, loss: 2.271784
# Epoch 41, loss: 2.279843
# Epoch 42, loss: 2.266811
# Epoch 43, loss: 2.270976
# Epoch 44, loss: 2.268005
# Epoch 45, loss: 2.272157
# Epoch 46, loss: 2.270150
# Epoch 47, loss: 2.265398
# Epoch 48, loss: 2.261528
# Epoch 49, loss: 2.263691
# Epoch 50, loss: 2.261998
# Epoch 51, loss: 2.258278
# Epoch 52, loss: 2.268870
# Epoch 53, loss: 2.276328
# Epoch 54, loss: 2.263036
# Epoch 55, loss: 2.262955
# Epoch 56, loss: 2.265360
# Epoch 57, loss: 2.251101
# Epoch 58, loss: 2.249303
# Epoch 59, loss: 2.266868
# Epoch 60, loss: 2.257189
# Epoch 61, loss: 2.257588
# Epoch 62, loss: 2.261293
# Epoch 63, loss: 2.256124
# Epoch 64, loss: 2.260975
# Epoch 65, loss: 2.258002
# Epoch 66, loss: 2.253780
# Epoch 67, loss: 2.242686
# Epoch 68, loss: 2.269460
# Epoch 69, loss: 2.245629
# Epoch 70, loss: 2.248276
# Epoch 71, loss: 2.240436
# Epoch 72, loss: 2.255676
# Epoch 73, loss: 2.244662
# Epoch 74, loss: 2.249075
# Epoch 75, loss: 2.262712
# Epoch 76, loss: 2.243093
# Epoch 77, loss: 2.257678
# Epoch 78, loss: 2.251521
# Epoch 79, loss: 2.243081
# Epoch 80, loss: 2.249455
# Epoch 81, loss: 2.242416
# Epoch 82, loss: 2.244502
# Epoch 83, loss: 2.253528
# Epoch 84, loss: 2.245081
# Epoch 85, loss: 2.235074
# Epoch 86, loss: 2.245078
# Epoch 87, loss: 2.232878
# Epoch 88, loss: 2.234592
# Epoch 89, loss: 2.234807
# Epoch 90, loss: 2.240199
# Epoch 91, loss: 2.250648
# Epoch 92, loss: 2.253816
# Epoch 93, loss: 2.230470
# Epoch 94, loss: 2.233139
# Epoch 95, loss: 2.256437
# Epoch 96, loss: 2.243038
# Epoch 97, loss: 2.246817
# Epoch 98, loss: 2.230498
# Epoch 99, loss: 2.239848
# Epoch 100, loss: 2.246654
# Epoch 101, loss: 2.227381
# Epoch 102, loss: 2.253368
# Epoch 103, loss: 2.238133
# Epoch 104, loss: 2.251626
# Epoch 105, loss: 2.236846
# Epoch 106, loss: 2.211483
# Epoch 107, loss: 2.228738
# Epoch 108, loss: 2.240565
# Epoch 109, loss: 2.236441
# Epoch 110, loss: 2.210625
# Epoch 111, loss: 2.241497
# Epoch 112, loss: 2.227661
# Epoch 113, loss: 2.230178
# Epoch 114, loss: 2.234173
# Epoch 115, loss: 2.239357
# Epoch 116, loss: 2.240433
# Epoch 117, loss: 2.217633
# Epoch 118, loss: 2.226999
# Epoch 119, loss: 2.220704
# Epoch 120, loss: 2.226125
# Epoch 121, loss: 2.229515
# Epoch 122, loss: 2.230434
# Epoch 123, loss: 2.250115
# Epoch 124, loss: 2.236790
# Epoch 125, loss: 2.223995
# Epoch 126, loss: 2.226637
# Epoch 127, loss: 2.237269
# Epoch 128, loss: 2.226104
# Epoch 129, loss: 2.237959
# Epoch 130, loss: 2.224843
# Epoch 131, loss: 2.202107
# Epoch 132, loss: 2.229628
# Epoch 133, loss: 2.231500
# Epoch 134, loss: 2.223915
# Epoch 135, loss: 2.238656
# Epoch 136, loss: 2.219893
# Epoch 137, loss: 2.215516
# Epoch 138, loss: 2.215293
# Epoch 139, loss: 2.233717
# Epoch 140, loss: 2.224773
# Epoch 141, loss: 2.203920
# Epoch 142, loss: 2.193089
# Epoch 143, loss: 2.206851
# Epoch 144, loss: 2.226264
# Epoch 145, loss: 2.232111
# Epoch 146, loss: 2.231132
# Epoch 147, loss: 2.205087
# Epoch 148, loss: 2.221793
# Epoch 149, loss: 2.209277
# Epoch 150, loss: 2.207657
# Epoch 151, loss: 2.211205
# Epoch 152, loss: 2.202444
# Epoch 153, loss: 2.203390
# Epoch 154, loss: 2.209182
# Epoch 155, loss: 2.222478
# Epoch 156, loss: 2.225642
# Epoch 157, loss: 2.209879
# Epoch 158, loss: 2.215467
# Epoch 159, loss: 2.229750
# Epoch 160, loss: 2.212113
# Epoch 161, loss: 2.228982
# Epoch 162, loss: 2.209128
# Epoch 163, loss: 2.223196
# Epoch 164, loss: 2.219021
# Epoch 165, loss: 2.184370
# Epoch 166, loss: 2.250517
# Epoch 167, loss: 2.238241
# Epoch 168, loss: 2.213466
# Epoch 169, loss: 2.234959
# Epoch 170, loss: 2.214266
# Epoch 171, loss: 2.211265
# Epoch 172, loss: 2.193852
# Epoch 173, loss: 2.220791
# Epoch 174, loss: 2.225013
# Epoch 175, loss: 2.195192
# Epoch 176, loss: 2.219597
# Epoch 177, loss: 2.204630
# Epoch 178, loss: 2.191975
# Epoch 179, loss: 2.187761
# Epoch 180, loss: 2.178349
# Epoch 181, loss: 2.198026
# Epoch 182, loss: 2.183340
# Epoch 183, loss: 2.231096
# Epoch 184, loss: 2.238889
# Epoch 185, loss: 2.211497
# Epoch 186, loss: 2.206886
# Epoch 187, loss: 2.235614
# Epoch 188, loss: 2.216087
# Epoch 189, loss: 2.213676
# Epoch 190, loss: 2.192026
# Epoch 191, loss: 2.219868
# Epoch 192, loss: 2.198926
# Epoch 193, loss: 2.194553
# Epoch 194, loss: 2.215231
# Epoch 195, loss: 2.213473
# Epoch 196, loss: 2.206217
# Epoch 197, loss: 2.191742
# Epoch 198, loss: 2.215303
# Epoch 199, loss: 2.202625
# Best validation accuracy achieved: 0.246

# %% [markdown]
# # Какой же точности мы добились на тестовых данных?

# %%
test_pred = best_classifier.predict(test_X)
test_accuracy = multiclass_accuracy(test_pred, test_y)
print(f'Linear softmax classifier test set accuracy: {test_accuracy}')
# Out:
# Linear softmax classifier test set accuracy: 0.202
